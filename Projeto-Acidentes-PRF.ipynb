# %%
import numpy as np

# %%
import pandas as pd

# %%
prf_2018 = pd.read_csv('https://arquivos.prf.gov.br/arquivos/index.php/s/MaC6cieXSFACNWT/download', compression='zip', encoding='latin1', sep=';')
prf_2019 = pd.read_csv('https://arquivos.prf.gov.br/arquivos/index.php/s/kRBUylqz6DyQznN/download', compression='zip', encoding='latin1', sep=';')
prf_2020 = pd.read_csv('https://arquivos.prf.gov.br/arquivos/index.php/s/35cUcYXWsrJd4tF/download', compression='zip', encoding='latin1', sep=';')
prf_2021 = pd.read_csv('https://arquivos.prf.gov.br/arquivos/index.php/s/n1T3lymvIdDOzzb/download', compression='zip', encoding='latin1', sep=';')

# %%
prf_2021.info()

# %%
acidentes = pd.merge(prf_2018, prf_2019, how="outer")

# %%
acidentes
# Out:
#               id data_inversa     dia_semana   horario  uf     br     km  \
# 0        99973.0   2018-01-01  segunda-feira  00:20:00  RJ  116.0  303,5
# 1        99976.0   2018-01-01  segunda-feira  00:40:00  SC  282.0    0,4
# 2        99977.0   2018-01-01  segunda-feira  00:30:00  RJ  493.0      1
# 3        99981.0   2018-01-01  segunda-feira  01:15:00  RS  386.0    134
# 4        99982.0   2018-01-01  segunda-feira  00:20:00  RS  293.0  151,7
# ...          ...          ...            ...       ...  ..    ...    ...
# 136736  266255.0   2019-10-07  segunda-feira  09:10:00  ES  101.0  270,5
# 136737  266406.0   2019-11-25  segunda-feira  07:20:00  PR  116.0    125
# 136738  266434.0   2019-06-03  segunda-feira  19:00:00  CE  222.0    1,4
# 136739  266573.0   2019-07-13         sábado  19:35:00  PR  373.0    425
# 136740  266627.0   2019-10-22    terça-feira  20:20:00  BA  324.0    608
#
#                  municipio                      causa_acidente  \
# ...

# %%
prf_2018
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 0       99973.0   2018-01-01  segunda-feira  00:20:00  RJ  116.0  303,5
# 1       99976.0   2018-01-01  segunda-feira  00:40:00  SC  282.0    0,4
# 2       99977.0   2018-01-01  segunda-feira  00:30:00  RJ  493.0      1
# 3       99981.0   2018-01-01  segunda-feira  01:15:00  RS  386.0    134
# 4       99982.0   2018-01-01  segunda-feira  00:20:00  RS  293.0  151,7
# ...         ...          ...            ...       ...  ..    ...    ...
# 69290  252256.0   2018-12-24  segunda-feira  09:15:00  PI  343.0  263,1
# 69291  252652.0   2018-12-12   quarta-feira  07:00:00  BA  101.0    321
# 69292  252801.0   2018-11-15   quinta-feira  10:48:00  SP  116.0    529
# 69293  253040.0   2018-11-23    sexta-feira  19:30:00  RS  472.0  573,5
# 69294  253078.0   2018-10-01  segunda-feira  04:31:00  GO   40.0      9
#
#                        municipio  \
# 0                        RESENDE
# ...

# %%
acidentes[acidentes['data_inversa'].str.contains("2019")]
# Out:
#               id data_inversa     dia_semana   horario  uf     br     km  \
# 69295   182210.0   2019-01-01    terça-feira  01:30:00  SP  116.0    218
# 69296   182211.0   2019-01-01    terça-feira  01:30:00  PR  373.0  177,3
# 69297   182212.0   2019-01-01    terça-feira  00:45:00  SC  101.0     16
# 69298   182214.0   2019-01-01    terça-feira  00:00:00  CE   20.0  429,5
# 69299   182215.0   2019-01-01    terça-feira  01:00:00  MG  381.0    327
# ...          ...          ...            ...       ...  ..    ...    ...
# 136736  266255.0   2019-10-07  segunda-feira  09:10:00  ES  101.0  270,5
# 136737  266406.0   2019-11-25  segunda-feira  07:20:00  PR  116.0    125
# 136738  266434.0   2019-06-03  segunda-feira  19:00:00  CE  222.0    1,4
# 136739  266573.0   2019-07-13         sábado  19:35:00  PR  373.0    425
# 136740  266627.0   2019-10-22    terça-feira  20:20:00  BA  324.0    608
#
#                  municipio                       causa_acidente  \
# ...

# %%
acidentes2 = prf_2018.merge(prf_2019, how='left').merge(prf_2020, how='left')

# %%
acidentes2
# Out:
#              id data_inversa     dia_semana   horario  uf     br     km  \
# 0       99973.0   2018-01-01  segunda-feira  00:20:00  RJ  116.0  303,5
# 1       99976.0   2018-01-01  segunda-feira  00:40:00  SC  282.0    0,4
# 2       99977.0   2018-01-01  segunda-feira  00:30:00  RJ  493.0      1
# 3       99981.0   2018-01-01  segunda-feira  01:15:00  RS  386.0    134
# 4       99982.0   2018-01-01  segunda-feira  00:20:00  RS  293.0  151,7
# ...         ...          ...            ...       ...  ..    ...    ...
# 69290  252256.0   2018-12-24  segunda-feira  09:15:00  PI  343.0  263,1
# 69291  252652.0   2018-12-12   quarta-feira  07:00:00  BA  101.0    321
# 69292  252801.0   2018-11-15   quinta-feira  10:48:00  SP  116.0    529
# 69293  253040.0   2018-11-23    sexta-feira  19:30:00  RS  472.0  573,5
# 69294  253078.0   2018-10-01  segunda-feira  04:31:00  GO   40.0      9
#
#                        municipio  \
# 0                        RESENDE
# ...
