# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('https://arquivos.prf.gov.br/arquivos/index.php/s/35cUcYXWsrJd4tF/download', compression='zip', encoding='latin1', sep=';', low_memory=False)

# %%
df
# Out:
#               id     pesid data_inversa dia_semana   horario  uf     br  \
# 0       260068.0  578549.0   2020-01-01     quarta  05:40:00  PA  316.0
# 1       260068.0  578550.0   2020-01-01     quarta  05:40:00  PA  316.0
# 2       260073.0  580299.0   2020-01-01     quarta  06:00:00  MG  262.0
# 3       260087.0  578794.0   2020-01-01     quarta  06:00:00  BA  116.0
# 4       260116.0  578657.0   2020-01-01     quarta  10:08:00  SP  116.0
# ...          ...       ...          ...        ...       ...  ..    ...
# 147637  352311.0  784912.0   2020-08-15    sÃ¡bado  18:30:00  RS  116.0
# 147638  352395.0  785081.0   2020-12-30     quarta  11:00:00  PI  343.0
# 147639  352395.0  785080.0   2020-12-30     quarta  11:00:00  PI  343.0
# 147640  352488.0  785255.0   2020-12-31     quinta  08:00:00  MA  135.0
# 147641  352488.0  785254.0   2020-12-31     quinta  08:00:00  MA  135.0
#
#            km              municipio  \
# 0          84  SAO FRANCISCO DO PARA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147642 entries, 0 to 147641
# Data columns (total 35 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      147642 non-null  float64
#  1   pesid                   147641 non-null  float64
#  2   data_inversa            147642 non-null  object
#  3   dia_semana              147642 non-null  object
#  4   horario                 147642 non-null  object
#  5   uf                      147642 non-null  object
#  6   br                      147241 non-null  float64
#  7   km                      147241 non-null  object
#  8   municipio               147642 non-null  object
#  9   causa_acidente          147642 non-null  object
#  10  tipo_acidente           147642 non-null  object
#  11  classificacao_acidente  147642 non-null  object
#  12  fase_dia                147642 non-null  object
#  13  sentido_via             147642 non-null  object
# ...

# %%
df['']
